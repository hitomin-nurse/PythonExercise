# %%
#学生名をどのようにきれいに取り出して表示するかの検討も必要

#Google Driveへのアクセス
import gspread
from oauth2client.service_account import ServiceAccountCredentials

SCOPES = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
SERVICE_ACCOUNT_FILE = 'attendance-analysis-3289d2b5d95d.json'

credentials = ServiceAccountCredentials.from_json_keyfile_name(SERVICE_ACCOUNT_FILE, SCOPES)

gs = gspread.authorize(credentials)
    

#関数を定義
def attendance(date, kind):

#SPREADSHEET_KEYに複数講義をfor文で代入
    classes = ['1iujppM7nPleunP6wTT2TTnCAm1MxbDNa1_JIoYvnxC8',
                '1mKkP2XgRFLnMo5ajUjmAFgyaOEV2A967vCq0PIKBfb8',
                '1LwlWzniMBwMpDUFFNwUUGGEfD97LR3XPcBAfViV8kc8',
                '1K_ENUB4kmbbuS-1Bv6Qhsokzx8PN1NS9uB3M5Npr-m8',
                '1GQjp2hU7oL91cBpbn9f0R-zTTmwvZla5KGMYbBicMjg',
                '1YVu5Rgttpu2vElkeLDL06EtJs95ez6aEq7l96d3Ru3E',
                '1iBgzaZL8fNFdAvu1yUfJoL4uPtZ1--OW7BnVldW0LcI',
                '11J7MYHNB8F86YSryYE2xCYV6__gLsxVA4VrqD9UE3IM',
                '1L14lMjjGdk8U3RFH0lLlifomsZfOe5W3oPxiz1AtnLQ',
                '185KJwm5HEmbcKtWqvgGf7J19VPNUFOgkoaBs9f7I7rM',
                '10a3cxbV9hcFDdwq0wI5ASSqcsdOyEVhvdw47ONG00wA',
                '1zr2wt_ZS4goP46u4ggLyOJLmUYArUT0m4rIwRgYuV8M',
                '15aScE3QEwPuSzcjGNpVuyS2HdmON8CKqbt0S1rcJPck',
                '18Ag8BnancRmebQf3g2PwO6Ez3BWoW4k1w7INOJpi5a4',
                '11yALsM1tFDALXsyxJsuIlZt3PWjoefIs6S-HW-tLQyU',
                '19-M_SK06VtECOlIw76t3YZGB0plDUZOtJ9X_dSpJAAI',
                '1IrjXrATiIeukc7Y5nScmbR3c5KNrWvn4iPaVncuVOPo',
                '1Iu8Yk0Lci9bsOHzWFejhAzseTnbclcN2fdNu_r0Y2CQ',
                '1RHZUBsHC59sa-KrFMVqUqWmaTV4SfjwKgPMCKB3D-uM',
                '1FfBILGI9fKw6JJWEIyxXUQoXMRWv0DFtlaWDbKGTmBc',
                '1FJhbkKdPaGCZuWhwczwfcDwDLYkdPHU8XoLgycvtm3s',
                '1oc8Icj6dACWolS13ixaWJtypiL-3JSoXwp-w6W_Q_iA',
                '1rt79IO2vqXEzX8pCJMKcnNxuEOnMew3fxxA6bQDIZ6I',
                '1sGRhjGdTBk2AK60ukludo5PVVp2IYUQXwfNnTnBfH1M',
                '15_GPAlU-0Upz8_SRP7ocUnk9LG9SmegFW_3TYS98T-s',
                '1tVr82LbOiGb4QReOfQ2JBB6RIRfoV6w5j1UGfANqTYQ',
                '1FOBQYqxMPvVJcr4FpIzynSRoZYMtlpiBMG5Rh9kTGyg',
                '1xclZkz7f9ig7M10xhDC-pYoQjeVQuLkKQy9LEvwKCbs',
                '1kEI2o9180qcswtTsHAWEN61vcfELqWfb9gIUj7KCNjY',
                '13ey853O77TRbsawkyLOOqSjO4WYCs64SW3e-3sMteoU',
                '1ibX1GlJwBr7GKIZeAnLQCSGVHwsHDNQ3swuVcMkPTsg',
                '1tjb_O1BGb_gW_hr6fqJk0WoouarChOhDwGLzSSIgo4I',
                '1bSMlD4z3fDyj7mm0kCtER7dZbQiKIovStsIK7pCmqR4',
                '13xppkd1M5tb50tyKe3jBQgCyfSN6_zy35pvopMaLgDY',
                '19uE-jY2i0-DnZ2WWPW1bgKx9FviG1jydjR0zzvYbfJQ',
                '1ULpFrApomjc0ShjbJ9iJb-T_N4FT_1i50fD62Bcapt4',
                '1mVjdemVpAP_H-rhsl4p5QhC1LaDc2l9ieb-bUwVGb4M',
                '119R-1U9XBf54VL8gT1tGzoqPWKxYI50Vm_FkGAsSnQ4',
                '1JHaDfZeR1KYXLCCr77yOvZFcmgvaZUODXlczBBrjgNs',
                '1LNHppQtXGil1Xf2SyXgBXFQYTZq92IBFZlzQHvfOG3s',
                '1BGixOfNMugq-vaDSajzgVIq60IEkmhzmUcPCrIvG_JM',
                '1uvug-Q3BntwJsmcmtKdWn7y4eQwkEWF61Tb9Yg2MVZk',
                '1gx1C6xKWTrlR8S_RZAXmu1NFKXm2K0rO0xDu9LVogbY',
                '1pUqVMGZ6t0e3WQYwCBTGS26I1zRFYq4qSuXXiEsd0xE',
                '1aSvenKyA9LVt9E16YpPr3lx4Uat_uRLV3_UDNTkSd1A',
                '1E5klnRW0ZwWx9QJo0lyPRUDOTrViFBOtA9-5GLESXx4',
                '1DMq8WtfxYEu_tmOelwx9dBsUd1YQ1WQfG8Tu0ajBvo8',
                '13nbDQt8fAOuCttr919VGWsNwIpZKZygIeMC9gnngIjg',
                '10CUsxHyrsJ_j0ELXyCc9GUBTMTeUe-5i-__RAnM-gK4',
                '1nbaiRbwZxVNTmlD-9-zxhifNcBWdGYOUAzGOlqvoaJ4',
                '1Pg165DgXe5ow18Oq81OqkZk4Omst55Emj38fMWDE17E',
                '1f35lIupgACSc3mF7t5-_uw6byt_Nfi9GcHxhJUi2KNU',
                '147NPcmdpU7Dmp6TwqV7GUY_M-P8wNKBQF257M-1naN4',
                '1MX2KawIdBtEh9VLtQW7832Wgp3kbSvZAFKSGXbfHjus',
                '1vmrdvV_te-C_TQaCPL-b1qy-pc86nrGWAENlf9x9vZQ',
                '1bNVpVkVZ_tGrW-h27qI3TXX_LS3CuFYvs8peTBNSHWI',
                '1BRGGFtYkT4793nC4NRiA78sZ5c9Hbc20Xba2xys_fQM',
                '1T4H12MnWhDGnjcNmmG5sPdzdHQsi-KsvaHy_9lFcVa8',
                '1yBJJ81PwM1fp1MJiyS50rU3E6WiGPCPqWsXJxT3IWrU',
                '1szyWa5W44sbZUl2Pc0hJvef-YlD5xYlldWqylYrm1oA',
                '12E6IH-moHp09b-rBVIeHOKhxuix2ins6w54H2viiL88',
                '16dHCL9m6m9cZTWsG4j4o632wLmDOE_-ZWBjlQFJ_feE',
                '1KSdsMPZtaPcls8eG55-zjLIOPDufK5Ir33VAq0IUF-8',
                '1fm5vMMqMUD0Pp_KbR6OBO2j9FpLtbSMK96vT7U2IAwg',
                '19q0KzE2tS8qCYhQl2HD916KizsWvbA-mY6UsD9zGV2s',
                '1h2GpXT4GImuQSn05sswOel_WLGWTpdVhojzLSTGrkFo',
                '17zMWZVuZMf9SzZM3d8i95mRt6_ABds3lWBAYXiIgdXE',
                '1HfMK4KHfE5JamkBV8OiynvKctyRaNzKhUrrQCCn8p-I',
                '1075nW5KphNWHoT4zmlqp86F0cJ94I_OMGe2v1dyEnb4',
                '12LN5nmELmfZNGtPY4nZx3CgSoeMNzqwS0GqcKdGwRFs',
                '1scnsf-bMB_OHSr8yDvdzaOaZNESE3J71sVguWRR_2ik',
                '1ji7YgZkYsqYAM16dusM241xl70vLvOIxyiw1jRq2peo',
                '1LseO5CvDTU-GwJBGqohMj4i_cRHarPid1UO618BYxoc',
                '1oggMBl5b9XIYAchb2zBh2gVawDkPLgNmAVn_iINP7Pg',
                '1yY7YRTk5tZk6dZv3pQVrgeTEVjNkbK74rpW28bcfpzA',
                '1GCNErTiHtPJEdpXXJJzB_E57hCe3JhdE3iAGah2dPpY',
                '1WkJMpaA08B4zFLsdEVHCIiPY-tWiBaYrn7qH8yWeFgU',
                '1zAvO88WaYZAgenal4wAHtTwl-kazu6P0-ZGbvrKcXvY',
                '10Vb3RrCwAhEawAkQFXx_IgSFcrOheA3rhqv1post1B4',
                '1bdjd_OS0QEvZ0vxI-ZmcMS5XvJFF6bqhbuY-naL0l_k/',
                '1OyWd0zqbDAO7cc93iQhGr_D1nbWCsL_5g07smX9XXBI',
                '163gZgfG499_lqlq3-N3zZOKoCaQe7Iq6HDBf9AfUu8k',
                '1xG2VtrBK5-TYaUpUdlS4j3m2uGspMrUgARDNptxnk8U',
                '1uB-UAEdJ_WDdX8WTyqZ0R7Y6NFnAPp5EH1XznBSWnak',
                '1jiVbr7FC2aDr5ZkL01PkvUlojk2jP4jrzTB3gX8jydw',
                '13U7BOV4j86GvvpiKEgKRpDJdENesTBGoy0ZCGnbc3EE',
                '1ppsQjjEZcRNjraBdAV7fYEhUBKkQWFI-cxoHwKBFNl8',
                '1IFsKUVohtSw9E3u3gyK2xuZYxwFXX_NNEq3p5PVr578',
                '1Q16pPVDlLYAN7QbrL8oQJMwFP1J8PmVWmS_5innV-lo',
                '1BBlViMKXso2YZadyO3hnBUAjDYLaeuOpiku1FHNuhvU',
                '1TMwnd-DkrTIXRx1YOQXP8Npj2v4bXAI1y5WvZERgyCg']
    
    for i in classes:
        
    #spreadsheetの取得
        SPREADSHEET_KEY = i
        worksheet = gs.open_by_key(SPREADSHEET_KEY).worksheet('出席')

        workbook = gs.open_by_key(SPREADSHEET_KEY)
        worksheet = workbook.worksheet('出席')

    #sheetの取得    
        import pandas as pd
        df = pd.DataFrame(worksheet.get_all_values())
        df2 = df.iloc[4:50, :]

    #必要範囲のみのDataFrame抽出   
        df2.columns = df2.iloc[0]
        df3 = df2.drop([4, 5, 6], axis = 0)
        df3 = df3.drop(['ヨミ'] , axis = 1)
        df3 = df3.drop('', axis = 1)

    #重複する列名の名前変更
        df3_columns = pd.Series(df3.columns)
        dup_date = df3_columns[df3_columns.duplicated()].unique()
        for dup in dup_date:
            df3_columns[df3_columns[df3_columns == dup].index.values.tolist()] = [dup + '-' + str(i +1) if i !=0 else dup for i in range(sum(df3_columns == dup))]
        df3.columns = df3_columns
        df3 = df3.reset_index(drop = True)

    #指定日該当箇所のみのDataFrame抽出
    #filter関数とfilterメソッドは別物らしいので注意．一致するものがなければ空白のDataFrameが返される．
        df4 = df3.filter(like = date)    

    #df4が空白であればここで終了
        if df4.empty == True:
            pass
    #df4が空でない場合は次へ進む
        else:
    
    #APIの制限を超えないよう休憩
           # import time
            #time.sleep(5)
    
    #「欠席者」「遅刻者」「出席者」の判断
            kind = str(kind)

        #kindの種類によって出力内容を変える
            if kind == '1':
                #DateFrameが1列か2列かで扱いが変わる
                if len(df4.columns) >1:
                    for i in [date, str(date+'-2')]:
                        index = df4[df4[i] == '1'].index
                        name = df3.iloc[index, 1]
                        print(workbook.title + 'の出席者は')
                        print(name)
                        #未記入項目がある場合に警告を表示
                        if sum(df4[i] == '') > 0:
                            print('【注意】' + workbook.title + 'には未記入項目が存在します')
                        else:
                            pass
                    else:
                        pass
            
                else:
                    index = df4[df4[date] == '1'].index
                    name = df3.iloc[index, 1]
                    print(workbook.title + 'の出席者は')
                    print(name)
                    #未記入項目がある場合に警告を表示
                    if sum(df4[date] == '') >0:
                        print('【注意】' + workbook.title + 'には未記入項目が存在します')
                    else:
                        pass

            elif kind == '0':
                #DateFrameが1列か2列かで扱いが変わる
                if len(df4.columns) >1:
                    for i in [date, str(date+'-2')]:
                        index = df4[df4[i] == '0'].index
                        name = df3.iloc[index, 1]
                        print(workbook.title + 'の欠席者は')
                        print(name)
                        #未記入項目がある場合に警告を表示
                        if sum(df4[i] == '') > 0:
                            print('【注意】' + workbook.title + 'には未記入項目が存在します')
                        else:
                            pass
                else:
                    index = df4[df4[date] == '0'].index
                    name = df3.iloc[index, 1]
                    print(workbook.title + 'の欠席者は')
                    print(name)
                    #未記入う項目がある場合に警告を表示
                    if sum(df4[date] == '') >0:
                        print('【注意】' + workbook.title + 'には未記入項目が存在します')
                    else:
                        pass

            elif kind == '0.5':
                #DateFrameが1列か2列かで扱いが変わる
                if len(df4.columns) >1:
                    for i in [date, str(date+'-2')]:
                        index = df4[df4[i] == '0.5'].index
                        name = df3.iloc[index, 1]
                        print(workbook.title + 'の遅刻者は')
                        print(name)
                        #未記入項目がある場合に警告を表示
                        if sum(df4[i] == '') > 0:
                            print('【注意】' + workbook.title + 'には未記入項目が存在します')
                        else:
                            pass
                else:
                    index = df4[df4[date] == '0.5'].index
                    name = df3.iloc[index, 1]
                    print(workbook.title + 'の遅刻者は')
                    print(name)
                    #未記入う項目がある場合に警告を表示
                    if sum(df4[date] == '') >0:
                        print('【注意】' + workbook.title + 'には未記入項目が存在します')
                    else:
                        pass

            else:
                print('検索対象の入力に誤りがあります')
            
#入力用
date = str(input('日付を入力してください'))
kind = str(input('検索対象を入力してください'))
attendance(date, kind)

print('検索が終了しました')
# Out:
# 日付を入力してください06/14
# 検索対象を入力してください0
# 月曜日_秘書検定3級対策B(後藤先生)の欠席者は
# 7      伊波 聖音
# 13    崎間 由里奈
# 20     通事 花蘭
# 21     仲村 妃奈
# Name: 氏名, dtype: object
# 月曜日_ビジネスマナー/サービス接遇検定C(後藤先生)の欠席者は
# 1     知名 そよか
# 3     真壁 明日香
# 13     伊波 聖音
# Name: 氏名, dtype: object
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# <ipython-input-13-766f3715dad8> in <module>
#     236 date = str(input('日付を入力してください'))
#     237 kind = str(input('検索対象を入力してください'))
# --> 238 attendance(date, kind)
#     239
#     240 print('検索が終了しました')
#
# <ipython-input-13-766f3715dad8> in attendance(date, kind)
#     120     #sheetの取得
#     121         import pandas as pd
# --> 122         df = pd.DataFrame(worksheet.get_all_values())
#     123         df2 = df.iloc[4:50, :]
#     124
#
# /usr/local/lib/python3.8/site-packages/gspread/models.py in get_all_values(self, value_render_option)
# ...
